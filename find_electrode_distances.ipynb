# %%
import math

# Define the dimensions of the electrode array
num_rows = 8
num_cols = 8
electrode_spacing = 0.2 # in mm

# Define a function to calculate the distance between two electrodes
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = math.sqrt((x2-x1)**2 + (y2-y1)**2)
    return distance

# Define a function to generate a list of electrode coordinates
def generate_electrode_coords(num_rows, num_cols, electrode_spacing):
    electrode_coords = []
    for row in range(num_rows):
        for col in range(num_cols):
            x = col * electrode_spacing
            y = row * electrode_spacing
            electrode_num = 10*(col+1) + (row+1)
            electrode_coords.append((x, y, electrode_num))
    return electrode_coords

# Generate a list of electrode coordinates for the MEA
electrode_coords = generate_electrode_coords(num_rows, num_cols, electrode_spacing)

# Calculate the distance between any two electrodes
electrode1 = 12 # electrode numbering starts from 11
electrode2 = 22
coord1 = next(coord for coord in electrode_coords if coord[2] == electrode1)
coord2 = next(coord for coord in electrode_coords if coord[2] == electrode2)
distance = calculate_distance(coord1[:2], coord2[:2])
print(f"Distance between electrodes {electrode1} and {electrode2}: {distance:.2f} mm")
# Out:
# Distance between electrodes 12 and 22: 0.20 mm

# %%
# Calculate the distance between any two electrodes
electrode1 = 12 # electrode numbering starts from 11
electrode2 = 71
coord1 = next(coord for coord in electrode_coords if coord[2] == electrode1)
coord2 = next(coord for coord in electrode_coords if coord[2] == electrode2)
distance = calculate_distance(coord1[:2], coord2[:2])
print(f"Distance between electrodes {electrode1} and {electrode2}: {distance:.2f} mm")
# Out:
# Distance between electrodes 12 and 71: 1.22 mm

# %%
elec_names=[('2020_02_04_l1_before_adch_17a', 33),
 ('2020_02_04_l1_before_adch_17b', 33),
 ('2020_02_04_l1_before_adch_17c', 33),
 ('2020_02_04_l1_before_adch_17d', 33),
 ('2020_02_04_l1_before_adch_22a', 33),
 ('2020_02_04_l1_before_adch_22b', 13),
 ('2020_02_04_l1_before_adch_28a', 22),
 ('2020_02_04_l1_before_adch_28c', 16),
 ('2020_02_04_l1_before_adch_31a', 15),
 ('2020_02_04_l1_before_adch_37a', 23),
 ('2020_02_04_l1_before_adch_37c', 16),
 ('2020_02_04_l1_before_adch_37d', 16),
 ('2020_02_04_l1_before_adch_38b', 33),
 ('2020_02_04_l1_before_adch_46b', 27),
 ('2020_02_04_l1_before_adch_46c', 21),
 ('2020_02_04_l1_before_adch_47f', 27),
 ('2020_02_04_l1_before_adch_48a', 15),
 ('2020_02_04_l1_before_adch_63a', 15),
 ('2020_02_04_l1_before_adch_63b', 15),
 ('2020_02_04_l1_before_adch_64a', 15),
 ('2020_02_04_l1_before_adch_64e', 26),
 ('2020_02_04_l1_before_adch_68a', 23),
 ('2020_02_04_l1_before_adch_68b', 23),
 ('2020_02_04_l1_before_adch_68c', 15),
 ('2020_02_04_l1_before_adch_74b', 2),
 ('2020_02_04_l1_before_adch_76c', 29),
 ('2020_02_04_l1_before_adch_77b', 31),
 ('2020_02_04_l1_before_adch_77c', 32),
 ('2020_02_04_l1_before_adch_78b', 22),
 ('2020_02_04_l1_before_adch_85b', 15),
 ('2020_02_04_l1_before_adch_87d', 6),
 ('2020_02_06_r1_before_adch_34a', 9),
 ('2020_02_06_r1_before_adch_45c', 15),
 ('2020_02_06_r1_before_adch_47b', 9),
 ('2020_06_03_l2_adch_14a', 22),
 ('2020_06_03_l2_adch_14d', 17),
 ('2020_06_03_l2_adch_16a', 32),
 ('2020_06_03_l2_adch_16d', 24),
 ('2020_06_03_l2_adch_16f', 32),
 ('2020_06_03_l2_adch_17b', 24),
 ('2020_06_03_l2_adch_25c', 23),
# dict_keys(['2020_01_17_rhalf1', '2020_01_25_r1', '2020_02_04_l1_before', '2020_02_06_r1_before', '2020_01_25_left', '2020_01_16_wl', '2020_06_03_l2', '2020_07_22', '2020_07_23_l1', '2020_07_23_r1', '2020_08_03_l1', '2020_08_03_r1', '2020_08_03_r2', '2020_08_04_r1', '2020_08_04_r2', '2020_08_l1'])

# %%
import random
import statistics

class elecdis:
    def __init__(self, names,stimelec,elec_names):
        self.names = names
        self.stimulus_electrode= stimelec
        exp_name=names

        self.recording_electrodes= [int(x[0][-3:-1]) for x in elec_names if exp_name in x[0]]


    # Define the dimensions of the electrode array
        self.num_rows = 8
        self.num_cols = 8
        self.electrode_spacing = 0.2 # in mm

    # Define a function to calculate the distance between two electrodes
    def calculate_distance(self,coord1, coord2):
        x1, y1 = coord1
        x2, y2 = coord2
        distance = math.sqrt((x2-x1)**2 + (y2-y1)**2)
        return distance

    # Define a function to generate a list of electrode coordinates
    def generate_electrode_coords(self,num_rows, num_cols, electrode_spacing):
        electrode_coords = []
        for row in range(num_rows):
            for col in range(num_cols):
                x = col * electrode_spacing
                y = row * electrode_spacing
                electrode_num = 10*(col+1) + (row+1)
                electrode_coords.append((x, y, electrode_num))
        return electrode_coords


 

    def find_all_distances(self):
        distances=[]
        for elec in self.recording_electrodes:
            electrode1 = elec # electrode numbering starts from 11
            electrode2 = self.stimulus_electrode
            electrode_coords=self.generate_electrode_coords(self.num_rows, self.num_cols, self.electrode_spacing)
            coord1 = next(coord for coord in electrode_coords if coord[2] == electrode1)
            coord2 = next(coord for coord in electrode_coords if coord[2] == electrode2)
            distances.append(self.calculate_distance(coord1[:2], coord2[:2]))
        return distances

# %%
elf.recording_electrodes
# Out:
# [14, 21, 31, 33, 35, 42, 43, 44, 45, 46, 53, 54, 56, 66, 84, 85]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Generate some example data to plot
exp_names=list(Filenames.keys())


# Define the number of subplots and the number of rows
n = len(exp_names)  # number of subplots
m = int(np.ceil(n / 4))  # number of rows

# Create a new figure
fig = plt.figure(figsize=(20, 3*m))

# Loop over each ]
for k,exp_name in enumerate(exp_names):

    elf=elecdis(exp_name,Filenames[exp_name]['stim_electrode'],elec_names)
    # Calculate the row and column indices
    row = k // 4
    col = k % 4
    
    # Add a new subplot to the figure
    ax = fig.add_subplot(m, 4, k+1)
    

    #ax=fighist.add_axes([i/len(exp_num),.1,1/len(exp_num)-.005,1/len(exp_num)-.015])
    ax = sns.distplot(elf.find_all_distances())
    # Set the title of the plot
    ax.set_title(elf.names+' elec='+str(elf.stimulus_electrode) )
    # Plot the data on this axis
    
    # Set the title of this subplot
    
    # Remove the x and y ticks
    #ax.set_xticks([])
    #ax.set_yticks([])

# Adjust the spacing between subplots
fig.subplots_adjust(hspace=0.5, wspace=0.5)

# Show the plot
plt.show()
# Out:
# c:\Users\hamed\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\hamed\anaconda3\lib\site-packages\seaborn\distributions.py:2657: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Users\hamed\AppData\Roaming\Python\Python38\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\hamed\AppData\Roaming\Python\Python38\site-packages\numpy\lib\histograms.py:906: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# ...

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# #exp_name=filenames[2][:-4]
# exp_names=list(Filenames.keys())
# fighist=plt.figure(figsize=(4,40))
# exp_num=exp_names
# #exp_cells= [int(x[0][-3:-1]) for x in cell_names if exp_name in x[0]]
# for i,exp_name in enumerate(exp_names):

#     elf=elecdis(exp_name,Filenames[exp_name]['stim_electrode'])
#     #distacne_all=elf.find_all_distances()
#     #print(elf.names,elf.stimulus_electrode ,elf.recording_electrodes,distacne_all)
#     ax=fighist.add_axes([i/len(exp_num),.1,1/len(exp_num)-.005,1/len(exp_num)-.015])


#     ax = sns.distplot(elf.find_all_distances())

#     # Set the title of the plot
#     ax.set_title(elf.names+'  stim elec='+str(elf.stimulus_electrode) )
# plt.show()

# %%
distance=[]
for i in elf.recording_electrodes:
    
    # Calculate the distance between any two electrodes
    electrode1 = i # electrode numbering starts from 11
    electrode2 = 62
    coord1 = next(coord for coord in electrode_coords if coord[2] == electrode1)
    coord2 = next(coord for coord in electrode_coords if coord[2] == electrode2)
    distance.append(calculate_distance(coord1[:2], coord2[:2]))
distance
# Out:
# [1.4142135623730951,
#  1.4142135623730951,
#  1.4142135623730951,
#  1.4142135623730951,
#  0.8,
#  0.8,
#  1.4422205101855958,
#  1.4422205101855958,
#  0.6324555320336759,
#  1.1661903789690602,
#  1.1661903789690602,
#  1.1661903789690602,
#  1.3416407864998738,
#  0.8944271909999159,
#  0.8944271909999159,
#  1.077032961426901,
#  1.2649110640673518,
#  0.2,
#  0.2,
#  0.4000000000000001,
#  0.4000000000000001,
#  1.2000000000000002,
#  1.2000000000000002,
#  1.2000000000000002,
#  0.4472135954999581,
#  0.8246211251235323,
#  1.0198039027185573,
#  1.0198039027185573,
#  1.216552506059644,
#  0.721110255092798,
#  1.077032961426901]

# %%
class Calculator:
    def __init__(self, precision):
        self.precision = precision

    def multiply(self, x, y):
        return round(x * y, self.precision)

    def division(self, x, y):
        if y == 0:
            raise ValueError("Cannot divide by zero")
        return round(x / y, self.precision)

# %%
# Create a new Calculator instance with precision of 2 decimal places
my_calculator = Calculator(precision=2)
my_calculator.multiply(2,3)
# Out:
# 6

# %%
num_rows = 8
num_cols = 8
electrode_spacing = 0.2 # in mm
# Generate a list of electrode coordinates for the MEA
electrode_coords = elf.generate_electrode_coords(num_rows, num_cols, electrode_spacing)
# Calculate the distance between any two electrodes
for elec in elf.exp_cells:
    electrode1 = elec # electrode numbering starts from 11
    electrode2 = 22
    coord1 = next(coord for coord in electrode_coords if coord[2] == electrode1)
    coord2 = next(coord for coord in electrode_coords if coord[2] == electrode2)
    distance = elf.calculate_distance(coord1[:2], coord2[:2])

# %%
elf.names.distance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 elf.names.distance
#
# AttributeError: 'str' object has no attribute 'distance'

# %%
elf.calculate_distance
# Out:
# <bound method elecdis.calculate_distance of <__main__.elecdis object at 0x000001F2E11C34C0>>

# %%
# Generate a list of electrode coordinates for the MEA
electrode_coords = generate_electrode_coords(num_rows, num_cols, electrode_spacing)

# %%
    # Generate a list of electrode coordinates for the MEA
    electrode_coords = generate_electrode_coords(num_rows, num_cols, electrode_spacing)

    # Calculate the distance between any two electrodes
    electrode1 = 12 # electrode numbering starts from 11
    electrode2 = 22
    coord1 = next(coord for coord in electrode_coords if coord[2] == electrode1)
    coord2 = next(coord for coord in electrode_coords if coord[2] == electrode2)
    distance = calculate_distance(coord1[:2], coord2[:2])
    print(f"Distance between electrodes {electrode1} and {electrode2}: {distance:.2f} mm")

# %%
names = ['Alice', 'Bob', 'Charlie']
rng = RandomNumberGenerator(names)
results = rng.compute()
print(results)
# Out:
# {'Alice': {'numbers': [0.7235945646320425, 0.08711948952897486, 0.36761488357659566, 0.24441435142582701, 0.35089908275338166], 'mean': 0.35472847438336436, 'stdev': 0.23453501381253541}, 'Bob': {'numbers': [0.04954830268891175, 0.8341175449642292, 0.2971538949406495, 0.01637283014826274, 0.14616442614314307], 'mean': 0.26867139977703924, 'stdev': 0.33437181928990123}, 'Charlie': {'numbers': [0.3992867883829425, 0.8454901681778341, 0.7567663007159394, 0.44010498269557274, 0.3808754282932937], 'mean': 0.5645047336531165, 'stdev': 0.2193224303673845}}
